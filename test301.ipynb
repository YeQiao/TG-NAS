# %%
import pickle

# Replace this path with the correct location of your nb301_full_training.pickle file
filename = '/shared/jingchl6/TG-NAS/NAS-Bench-Suite-Zero/nb301_full_training.pickle'

with open(filename, 'rb') as f:
    data = pickle.load(f)

print("Type of data:", type(data))
if isinstance(data, dict):
    print("Keys in the dictionary:", list(data.keys()))
elif isinstance(data, list):
    print("Number of entries in the list:", len(data))
    # Print a sample entry to inspect its structure
    print("Sample entry:", data[0])
else:
    print("Data structure:", data)
# Out:
# Type of data: <class 'dict'>
# ...

# %%
import pickle

filename = '/shared/jingchl6/TG-NAS/NAS-Bench-Suite-Zero/nb301_full_training.pickle'
with open(filename, 'rb') as f:
    data = pickle.load(f)

# Get one sample key and its corresponding value
sample_key = list(data.keys())[0]
sample_value = data[sample_key]
print("Sample architecture representation (key):")
print(sample_key)
print("\nSample performance metrics (value):")
print(sample_value)
# Out:
# Sample architecture representation (key):
# (((0, 6), (1, 4), (0, 0), (1, 5), (1, 4), (3, 2), (0, 6), (3, 2)), ((0, 1), (1, 4), (0, 1), (1, 4), (2, 6), (3, 4), (1, 5), (2, 1)))
#
# Sample performance metrics (value):
# ...
